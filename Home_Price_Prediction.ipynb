# %% [markdown]
# # **Home Price Prediction Using Linear Regression**
#
# **Project Description**
#
# This project aims to predict house prices based on the area (in square feet) using Linear Regression, a supervised machine learning algorithm. The dataset consists of house areas and their corresponding prices. The model learns the relationship between area and price and uses this relationship to predict the price of a house for a given area.
#
# **Key steps include:**
#
# Data creation and preprocessing
#
# *  Data creation and preprocessing
# *  Visualization using scatter plot
# *  Training a linear regression model
# *  Predicting house prices
# *  Evaluating model parameters (slope and intercept)
# * Plotting the regression line

# %%
# Import required libraries
import pandas as pd                  # For data handling
import matplotlib.pyplot as plt      # For visualization
from sklearn.linear_model import LinearRegression  # Linear Regression model

# %% [markdown]
# # **Step 1: Create Dataset**

# %%
data= {
    "area" : [2600, 3000,3200,3600,4000],
    "price" :[550000, 565000,610000,680000,725000]
}
df = pd.DataFrame(data)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # **Step 2: Data Visualization**

# %%
# Plot scatter graph to understand relationship
plt.xlabel("Area (sqr ft)")
plt.ylabel ("Price (in INR)")
plt.title("Home price Vs Area")
plt.scatter(df.area, df.price, color ='red', marker='*')
plt.show()

# %% [markdown]
# # **Step 3: Train Linear Regression Model**

# %%
# Train the model using area as input and price as output
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [markdown]
# # Concept of LInear regression prediction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Linear Regression fits a straight line:
#      y= mx+b
#
# **Price = (Slope × Area) + Intercept**
#
# **Slope= Sum of product deviation / Sum of square of deviation for x**
#
# Intercept = Mean of y - (m* mean of x)

# %% [markdown]
# # **Step 4: Make Predictions**

# %%
# Predict price for a new area
reg.predict([[2600]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %% [markdown]
# # **Step 5: Model Parameters**

# %%
# Coefficient (slope)
reg.coef_
# Out:
# array([135.78767123])

# %%
# Intercept
reg.intercept_

# %% [markdown]
# # **Step 6: Plot Regression Line**

# %%
# Scatter plot (actual data)
plt.scatter(df.area, df.price, color='red', marker='*', label="Actual Data")

# Regression line
plt.plot(df.area, reg.predict(df[["area"]]), color='blue', label="Regression Line")
# Labels and title
plt.xlabel("Area (Square Feet)")
plt.ylabel("Price (INR)")
plt.title("Linear Regression Fit")

# Show legend
plt.legend()

# Display graph
plt.show()

# %% [markdown]
# #                               --------End of project--------
